# %% [markdown]
# Based on the vancouver_housing_price.csv data, build a linear regression model to predict reasonable housing prices:
#
#     Use area as the input variable to build a single-variable model, evaluate the model's performance, and visualize the linear regression prediction results.
#
#     Use income, house age, number of rooms, population, and area as input variables to build a multi-variable model, and evaluate the model's performance.
#
#     Predict the reasonable housing price for the scenario where Income=65000, House Age=5, Number of Rooms=5, Population=30000, and Area=200.
#
#     X_test = [65000, 5, 5, 30000, 200]

# %%
#load the data
import pandas as pd
import numpy as np
data = pd.read_csv('vancouver_housing_price.csv')
data.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0       79545.45857             5.317139                   7.009188
# 1       79248.64245             4.997100                   6.730821
# 2       61287.06718             5.134110                   8.512727
# 3       63345.24005             3.811764                   5.586729
# 4       59982.19723             5.959445                   7.839388
#
#    Area Population        size         Price
# 0      23086.80050  188.214212  1.059034e+06
# 1      40173.07217  160.042526  1.505891e+06
# 2      36882.15940  227.273545  1.058988e+06
# 3      34310.24283  164.816630  1.260617e+06
# 4      26354.10947  161.966659  6.309435e+05

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(10,10))
fig1 =plt.subplot(231)
plt.scatter(data.loc[:,'Avg. Area Income'],data.loc[:,'Price'])
plt.title('Price VS Income')

fig2 =plt.subplot(232)
plt.scatter(data.loc[:,'Avg. Area House Age'],data.loc[:,'Price'])
plt.title('Price VS House Age')

fig3 =plt.subplot(233)
plt.scatter(data.loc[:,'Avg. Area Number of Rooms'],data.loc[:,'Price'])
plt.title('Price VS Number of Rooms')

fig4 =plt.subplot(234)
plt.scatter(data.loc[:,'Area Population'],data.loc[:,'Price'])
plt.title('Price VS Area Population')

fig5 =plt.subplot(235)
plt.scatter(data.loc[:,'size'],data.loc[:,'Price'])
plt.title('Price VS size')
plt.show()

# %%
#define X and y
X = data.loc[:,'size']
y = data.loc[:,'Price']
y.head()
# Out:
# 0    1.059034e+06
# 1    1.505891e+06
# 2    1.058988e+06
# 3    1.260617e+06
# 4    6.309435e+05
# Name: Price, dtype: float64

# %%
X = np.array(X).reshape(-1,1)
print(X.shape)
# Out:
# (5000, 1)

# %%
#set up the linear regression model
from sklearn.linear_model import LinearRegression
LR1 = LinearRegression()
#train the model
LR1.fit(X,y)
# Out:
# LinearRegression()

# %%
#calculate the price vs size
y_predict_1 = LR1.predict(X)
print(y_predict_1)
# Out:
# [1276881.85636623 1173363.58767144 1420407.32457443 ... 1097848.86467426
#  1264502.88144558 1131278.58816273]

# %%
#evaluate the model
from sklearn.metrics import mean_squared_error,r2_score
mean_squared_error_1 = mean_squared_error(y,y_predict_1)
r2_score_1 = r2_score(y,y_predict_1)
print(mean_squared_error_1,r2_score_1)
# Out:
# 108771672553.62639 0.1275031240418235

# %%
fig6 = plt.figure(figsize=(8,5))
plt.scatter(X,y)
plt.plot(X,y_predict_1,'r')
plt.show()

# %%
#define X_multi
X_multi = data.drop(['Price'],axis=1)
X_multi
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0          79545.45857             5.317139                   7.009188
# 1          79248.64245             4.997100                   6.730821
# 2          61287.06718             5.134110                   8.512727
# 3          63345.24005             3.811764                   5.586729
# 4          59982.19723             5.959445                   7.839388
# ...                ...                  ...                        ...
# 4995       60567.94414             3.169638                   6.137356
# 4996       78491.27543             4.000865                   6.576763
# 4997       63390.68689             3.749409                   4.805081
# 4998       68001.33124             5.465612                   7.130144
# 4999       65510.58180             5.007695                   6.792336
#
#       Area Population        size
# 0         23086.80050  188.214212
# 1         40173.07217  160.042526
# ...

# %%
#set up 2nd linear model
LR_multi = LinearRegression()
#train the model
LR_multi.fit(X_multi,y)
# Out:
# LinearRegression()

# %%
#make prediction
y_predict_multi = LR_multi.predict(X_multi)
print(y_predict_multi)
# Out:
# [1223968.89166047 1497306.33188641 1250884.3101944  ... 1020693.92390367
#  1260503.36914605 1302737.7915766 ]

# %%
mean_squared_error_multi = mean_squared_error(y,y_predict_multi)
r2_score_multi = r2_score(y,y_predict_multi)
print(mean_squared_error_multi,r2_score_multi)
# Out:
# 10219846512.17786 0.9180229195220739

# %%
print(mean_squared_error_1)
# Out:
# 108771672553.62639

# %%
fig7 = plt.figure(figsize=(8,5))
plt.scatter(y,y_predict_multi)
plt.show()

# %%
fig8 = plt.figure(figsize=(8,5))
plt.scatter(y,y_predict_1)
plt.show()

# %%
X_test = [55000,5,5,30000,200]
X_test = np.array(X_test).reshape(1,-1)
print(X_test)
# Out:
# [[55000     5     5 30000   200]]

# %%
y_test_predict = LR_multi.predict(X_test)
print(y_test_predict)
# Out:
# [600741.02552216]
# /opt/anaconda3/envs/allenai/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [raw]
# 线性回归房价实战summary：
# 1、通过搭建线性回归模型，实现单因子的房屋价格预测；
# 2、在单因子模型效果不好的情况下，通过考虑更多的因子，建立了多因子模型；
# 3、多因子模型达到了更好的预测效果，r2分数为0.91；
# 4、实现了预测结果的可视化，直观对比预测价格与实际价格的差异。
